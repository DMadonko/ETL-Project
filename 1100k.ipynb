# %%
import os
import csv
import pandas as pd

# %%
file = 'book1000k-1100k.csv'

# %%
df = pd.read_csv(file, encoding="ISO-8859-1")

# %%
df.head()
# Out:
#         Id                                 Name               Authors  \
# 0  1000000                     Flight from Eden     Kathryn A. Graham
# 1  1000001                      Roommates Again  Kathryn O. Galbraith
# 2  1000003                 The King At The Door            Brock Cole
# 3  1000004  Giotto: The Scrovegni Chapel, Padua            Bruce Cole
# 4  1000005                          Larky Mavis            Brock Cole
#
#          ISBN  Rating  PublishYear  PublishMonth  PublishDay  \
# 0  0595199402    4.00         2001             1          10
# 1  0689505973    3.20         1994             1           4
# 2  0374440417    3.95         1992            31          12
# 3  080761310X    4.47         1993             1           8
# 4  0374343659    3.69         2001             3           8
#
#                          Publisher RatingDist5 RatingDist4 RatingDist3  \
# 0          Writer's Showcase Press         5:1         4:1         3:1
# ...

# %%
df.count()
# Out:
# Id                       39705
# Name                     39705
# Authors                  39705
# ISBN                     39577
# Rating                   39705
# PublishYear              39705
# PublishMonth             39705
# PublishDay               39705
# Publisher                39345
# RatingDist5              39705
# RatingDist4              39705
# RatingDist3              39705
# RatingDist2              39705
# RatingDist1              39705
# RatingDistTotal          39705
# CountsOfReview           39705
# Language                  7013
# pagesNumber              39705
# Description              34559
# Count of text reviews    39705
# dtype: int64

# %%
cleandf = df[['ISBN','Name','Authors','Language','pagesNumber','Publisher','PublishYear','Rating']]
cleandf
# Out:
#              ISBN                                               Name  \
# 0      0595199402                                   Flight from Eden
# 1      0689505973                                    Roommates Again
# 2      0374440417                               The King At The Door
# 3      080761310X                Giotto: The Scrovegni Chapel, Padua
# 4      0374343659                                        Larky Mavis
# ...           ...                                                ...
# 39700  0394910095        The Cat in the Hat Beginner Book Dictionary
# 39701  0375922768  Oh Say Can You Say What's the Weather Today?: ...
# 39702  189020644X  Jewels on the Crescent: Masterpieces of the Ch...
# 39703  0064430170                                     Goodnight Moon
# 39704  0312856431                               The Voices of Heaven
#
#                     Authors Language  pagesNumber  \
# 0         Kathryn A. Graham      NaN          380
# ...

# %%
cleandf = cleandf.dropna(how='any')

# %%
cleandf.count()
# Out:
# ISBN           6842
# Name           6842
# Authors        6842
# Language       6842
# pagesNumber    6842
# Publisher      6842
# PublishYear    6842
# Rating         6842
# dtype: int64
