# %%
import pandas as pd
import os
import requests
import json
import api_keys

# %%
dataDir='data'

column_names=['ISBN',
             'Name',
             'Authors',
             'Description',
             'Language',
             'pagesNumber',
             'Publisher',
             'PublishYear',
             'Rating',
             'CountsOfReview']

mainData=pd.DataFrame(columns = column_names)

# Loop through each file in the data directory and load the files in a dataframe for ETL
for file in os.listdir(dataDir):
    filePath = '' + dataDir + '/' + os.fsdecode(file)
    df = pd.read_csv(filePath)
    # workaround for files without 'description' column
    if 'Description' not in df.columns:
        df['Description']="None"
    # initial stage of ETL - filter required columns
    df = df[['ISBN',
             'Name',
             'Authors',
             'Description',
             'Language',
             'pagesNumber',
             'Publisher',
             'PublishYear',
             'Rating',
             'CountsOfReview']]
    # remove non-english characters from Name and Author
    df['Name']=df['Name'].str.replace('[^a-zA-Z0-9!@#$%^&*()-+?/`~"\':; ]', '')
    df['Authors']=df['Authors'].str.replace('[^a-zA-Z0-9!@#$%^&*()-+?/`~"\':; ]', '')
    # drop rows with missing values
    df.dropna(how='any',inplace=True)
    # append CSV data to main dataframe
    mainData = mainData.append(df,ignore_index=True)

# %%
mainData
# Out:
#              ISBN                                               Name  \
# 0      0439358078  Harry Potter and the Order of the Phoenix (Har...
# 1      0439554896  Harry Potter and the Chamber of Secrets (Harry...
# 2      043965548X  Harry Potter and the Prisoner of Azkaban (Harr...
# 3      0439682584  Harry Potter Boxed Set Books 15 (Harry Potter ...
# 4      0976540606  Unauthorized Harry Potter Book Seven News: "Ha...
# ...           ...                                                ...
# 66029  0761989269                        Introduction to Museum Work
# 66030  0679723420                                          Pale Fire
# 66031  0689874464  Amelia's Book of Notes & Note Passing (Amelia'...
# 66032  0934052379                                      Passing It On
# 66033  0142401137               Sadako and the Thousand Paper Cranes
#
#                      Authors Description Language pagesNumber  \
# 0                 JK Rowling        None      eng         870
# 1                 JK Rowling        None      eng         352
# 2                 JK Rowling        None      eng         435
# 3                 JK Rowling        None      eng        2690
# 4      W Frederick Zimmerman        None    en-US         152
# ...                      ...         ...      ...         ...
# 66029         G Ellis Burcaw        None    en-GB         240
# 66030       Vladimir Nabokov        None      eng         315
# 66031           Marissa Moss        None      eng          80
# 66032         Yuri Kochiyama        None      eng         223
# 66033          Eleanor Coerr        None      eng          80
#
#                                       Publisher PublishYear  Rating  \
# 0                               Scholastic Inc.        2004    4.50
# 1                                    Scholastic        2003    4.42
# 2                               Scholastic Inc.        2004    4.57
# 3                                    Scholastic        2004    4.78
# 4                                  Nimble Books        2005    3.79
# ...                                         ...         ...     ...
# 66029                            AltaMira Press        1975    3.03
# 66030                                   Vintage        1989    4.15
# 66031  Simon & Schuster Books for Young Readers        2006    3.87
# 66032  UCLA Asian American Studies Center Press        2004    4.14
# 66033                              Puffin Books        2004    4.12
#
#       CountsOfReview
# 0              29770
# 1                244
# 2              37093
# 3                166
# 4                  1
# ...              ...
# 66029              3
# 66030            353
# 66031             11
# 66032              8
# 66033             58
#
# [66034 rows x 10 columns]

# %%
# View distinct languages
mainData.Language.unique()
# Out:
# array(['eng', 'en-US', 'fre', 'spa', 'mul', 'en-GB', 'grc', 'enm',
#        'en-CA', 'ger', 'jpn', 'ara', 'nl', 'zho', 'lat', 'por', 'srp',
#        'ita', 'rus', 'msa', 'glg', 'wel', 'swe', 'nor', 'kor', 'tur',
#        'gla', 'lit', 'per', 'pol', 'gle', 'cat', 'afr', 'ind', 'frs',
#        'sco', 'nav', 'gre', 'urd', 'elx', '--', 'cze', 'tlh', 'ang',
#        'hin', 'raj', 'nub', 'fin', 'dan', 'heb', 'ypk', 'lao', 'hye',
#        'fil', 'frm', 'tgl', 'wak'], dtype=object)

# %%
# filter languages & drop duplicates
enLanguages=['en-US','eng','en-GB','en-CA']
# sorting will keep the records with most reviews when duplicates are dropped
mainData2.sort_values(by='CountsOfReview',ascending=0,inplace=True)
mainData2 = mainData[mainData.Language.isin(enLanguages)].drop_duplicates()
#mainData2.drop_duplicates(subset='ISBN',inplace=True)
#mainData2.drop_duplicates(subset='Name',inplace=True)
# Convert certain columns to INT
mainData2['CountsOfReview']=mainData2['CountsOfReview'].astype(int)
mainData2['pagesNumber']=mainData2['pagesNumber'].astype(int)
mainData2['PublishYear']=mainData2['PublishYear'].astype(int)
mainData2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 61048 entries, 0 to 66033
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ISBN            61048 non-null  object
#  1   Name            61048 non-null  object
#  2   Authors         61048 non-null  object
#  3   Description     61048 non-null  object
#  4   Language        61048 non-null  object
#  5   pagesNumber     61048 non-null  int32
#  6   Publisher       61048 non-null  object
#  7   PublishYear     61048 non-null  int32
#  8   Rating          61048 non-null  float64
#  9   CountsOfReview  61048 non-null  int32
# dtypes: float64(1), int32(3), object(6)
# memory usage: 4.4+ MB

# %%
mainData2.sort_values(by='Name',inplace=True)

# %%
mainData2
# Out:
#              ISBN                                               Name  \
# 37344  4770027036                            / The Tale Of Genji: 22
# 14774  0821224964                                    Propos de Paris
# 1653   0743470796                       said the shotgun to the head
# 53413  0060541644  "A Problem from Hell": America and the Age of ...
# 9926   0310243564  "A" Is for Abductive : The Language of the Eme...
# ...           ...                                                ...
# 49849  0131495054         xUnit Test Patterns: Refactoring Test Code
# 37137  0345470583                       xxxHolic Vol 1 (xxxHOLiC #1)
# 37140  0345471199                      xxxHolic Vol 2  (xxxHOLiC #2)
# 37138  0345471814                      xxxHolic Vol 3  (xxxHOLiC #3)
# 37139  0345483359                      xxxHolic Vol 7  (xxxHOLiC #7)
#
#                     Authors Description Language  pagesNumber  \
# 37344           Waki Yamato        None      eng          160
# 14774  Henri CartierBresson        None      eng          168
# 1653          Saul Williams        None    en-US          192
# 53413        Samantha Power        None      eng          620
# 9926          Leonard Sweet        None    en-US          338
# ...                     ...         ...      ...          ...
# 49849       Gerard Meszaros        None      eng          883
# 37137                 CLAMP        None    en-US          178
# 37140                 CLAMP        None      eng          208
# 37138                 CLAMP        None      eng          182
# 37139                 CLAMP        None      eng          192
#
#                          Publisher  PublishYear  Rating  CountsOfReview
# 37344                          講談社         2001    0.00               0
# 14774                     Bulfinch         1998    4.65               3
# 1653                     MTV Books         2003    4.22             215
# 53413                  Basic Books         2003    4.23             447
# 9926                     Zondervan         2002    3.14               3
# ...                            ...          ...     ...             ...
# 49849  Addison-Wesley Professional         2007    3.94              43
# 37137                      Del Rey         2004    4.15             352
# 37140                      Del Rey         2004    4.19              88
# 37138                      Del Rey         2004    4.22              71
# 37139                Del Rey Books         2006    4.33              36
#
# [61048 rows x 10 columns]

# %%
dataCut=mainData2.head(50).reset_index()
dataCut
# Out:
#     index        ISBN                                               Name  \
# 0   37344  4770027036                            / The Tale Of Genji: 22
# 1   14774  0821224964                                    Propos de Paris
# 2    1653  0743470796                       said the shotgun to the head
# 3   53413  0060541644  "A Problem from Hell": America and the Age of ...
# 4    9926  0310243564  "A" Is for Abductive : The Language of the Eme...
# 5   21190  0446674060  "A" Is for Admission: The Insider's Guide to G...
# 6   37264  0761128050          "A" Is for Adultery Angst and Adults Only
# 7   48896  0060932333       "A" Is for Attitude : An Alphabet for Living
# 8   21196  0385471270  "An Honorable Profession": A Tribute to Robert...
# 9    9079  0070183171  "Dear Genius": A Memoir of My Life with Truman...
# 10  65613  1573922374  "Dumbth": The Lost Art of Thinking With 101 Wa...
# 11  21491  0292713428  "Evil" Arabs in American Popular Film: Orienta...
# 12  22431  0590020498                             "I Can't" Said The Ant
# 13  57625  0674468856  "It Changed My Life": Writings on the Women's ...
# 14  44434  2718117524                  "Le Rouge Et Le Noir" De Stendhal
# 15  50336  0884943208  "Listen Mom And Dad": Young Adults Look Back o...
# 16  24024  0740715267  "My Teenage Son's Goal In Life Is To Make Me F...
# 17  49471  0393317900  "One Hell of a Gamble": Khrushchev Castro and ...
# 18  33623  0226284352                      "Race" Writing and Difference
# 19  60302  0803229526  "Real" Indians and Others: MixedBlood Urban Na...
# 20  55550  0142408476              "Slowly Slowly Slowly" said the Sloth
# 21   1412  0688093388  "Stand Back" Said the Elephant "I'm Going to S...
# 22  65654  0801485487  "Strong of Body Brave and Noble": Chivalry and...
# 23  16971  0813523168                                            "Sweat"
# 24  37513  0813521378                   "Tell Me a Riddle": Tillie Olsen
# 25  49733  0295952857     "The Factory Ship" and "The Absentee Landlord"
# 26  34233  0140815244    "The Room In The Tower" And Other Ghost Stories
# 27  27415  0804723613  "This Culture of Ours": Intellectual Transitio...
# 28  26243  0818403128       "What's Happening to Me?" A Guide to Puberty
# 29  62807  0380721139                  "Who Was That Masked Man Anyway?"
# 30   4072  0465083617  "Why Are All The Black Kids Sitting Together i...
# 31  40078  0758210264                            "Wicked" Women Whodunit
# 32  40079  0758209355                              "Wicked" Women on Top
# 33  14454  0807735663  "You Gotta Be the Book": Teaching Engaged and ...
# 34  65099  0195160215  "they Say": Ida B Wells and the Reconstruction...
# 35   3674  1592000673  $30 Film School: How to Write Direct Produce S...
# 36  52060  1902638247  '95'98 Selected Work: Song from a Forgotten Ci...
# 37  43837  0571190146                                              'Art'
# 38  30345  0340677570  'Final Solution': Nazi Population Policy and t...
# 39  41112  0802841066  'In the Beginning' A Catholic Understanding of...
# 40  26817  0719059569  'Love Me Or Kill Me': Sarah Kane and the Theat...
# 41   1415  0385516487                                       'Salem's Lot
# 42  12118  0060539763  'Scuse Me While I Whip This Out: Reflections o...
# 43  32468  0226294277  'There Ain't no Black in the Union Jack': The ...
# 44  50295  0446614939  'Til Death Do Us Part (Bailey Weggins Mystery #3)
# 45  20563  0192834495            'Tis Pity She's a Whore and Other Plays
# 46  22090  0684848783                                     'Tis: A Memoir
# 47  25073  0316107093  'Toons for Our Times: A Bloom County Book of H...
# 48  65787  0763631183  'Twas the Night Before Christmas: or Account  ...
# 49  50939  0370004973           'Vogue's' Book Of Houses Gardens People;
#
#                         Authors Description Language  pagesNumber  \
# 0                   Waki Yamato        None      eng          160
# 1          Henri CartierBresson        None      eng          168
# 2                 Saul Williams        None    en-US          192
# 3                Samantha Power        None      eng          620
# 4                 Leonard Sweet        None    en-US          338
# 5            Michele A Hernndez        None    en-US          288
# 6                    Sara Midda        None    en-GB           64
# 7       Patricia RussellMcCloud        None    en-US          256
# 8               Pierre Salinger        None      eng          212
# 9                   Jack Dunphy        None      eng          275
# 10                  Steve Allen        None    en-US          390
# 11           Tim Jon Semmerling        None      eng          303
# 12                Polly Cameron        None      eng           36
# 13                Betty Friedan        None      eng          528
# 14        Pierre Georges Castex        None      eng          187
# 15             Orson Scott Card        None      eng          166
# 16                   Dave Barry        None      eng          112
# 17           Aleksandr Fursenko        None      eng          420
# 18         Henry Louis Gates Jr        None      eng          428
# 19              Bonita Lawrence        None      eng          303
# 20                   Eric Carle        None      eng           32
# 21              Patricia Thomas        None      eng           32
# 22  Constance Brittain Bouchard        None      eng          232
# 23           Zora Neale Hurston        None      eng          233
# 24  Deborah Silverton Rosenfelt        None      eng          326
# 25             Takiji Kobayashi        None      eng          185
# 26              Rudyard Kipling        None      eng           48
# 27                  Peter K Bol        None      eng          532
# 28                  Peter Mayle        None      eng           56
# 29                          Avi        None      eng          176
# 30         Beverly Daniel Tatum        None    en-US          320
# 31          MaryJanice Davidson        None      eng          320
# 32                Tina  Donahue        None      eng          296
# 33            Jeffrey D Wilhelm        None      eng          208
