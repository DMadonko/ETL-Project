# %%
import pandas as pd
import os
import requests
import json
import api_keys

# %%
dataDir='data'

column_names=['ISBN',
             'Name',
             'Authors',
             'Description',
             'Language',
             'pagesNumber',
             'Publisher',
             'PublishYear',
             'Rating',
             'CountsOfReview']

mainData=pd.DataFrame(columns = column_names)

# Loop through each file in the data directory and load the files in a dataframe for ETL
for file in os.listdir(dataDir):
    filePath = '' + dataDir + '/' + os.fsdecode(file)
    df = pd.read_csv(filePath)
    # workaround for files without 'description' column
    if 'Description' not in df.columns:
        df['Description']="None"
    # initial stage of ETL - filter required columns
    df = df[['ISBN',
             'Name',
             'Authors',
             'Description',
             'Language',
             'pagesNumber',
             'Publisher',
             'PublishYear',
             'Rating',
             'CountsOfReview']]
    # remove non-english characters from Name and Author
    df['Name']=df['Name'].str.replace('[^a-zA-Z0-9!@#$%^&*()-+?/`~"\':; ]', '')
    df['Authors']=df['Authors'].str.replace('[^a-zA-Z0-9!@#$%^&*()-+?/`~"\':; ]', '')
    # drop rows with missing values
    df.dropna(how='any',inplace=True)
    # append CSV data to main dataframe
    mainData = mainData.append(df,ignore_index=True)

# %%
mainData
# Out:
#              ISBN                                               Name  \
# 0      0439358078  Harry Potter and the Order of the Phoenix (Har...
# 1      0439554896  Harry Potter and the Chamber of Secrets (Harry...
# 2      043965548X  Harry Potter and the Prisoner of Azkaban (Harr...
# 3      0439682584  Harry Potter Boxed Set Books 15 (Harry Potter ...
# 4      0976540606  Unauthorized Harry Potter Book Seven News: "Ha...
# ...           ...                                                ...
# 45740  0813311594  The Center Of The Universe: The Geopolitics Of...
# 45741  0883650975                  Gloria Vanderbilt Book Of Collage
# 45742  0310295610                               Who Moved the Stone?
# 45743  0786867280                                         Silent Joe
# 45744  1574883453  Silent Warfare: Understanding the World of Int...
#
#                      Authors Description Language pagesNumber  \
# 0                 JK Rowling        None      eng         870
# 1                 JK Rowling        None      eng         352
# 2                 JK Rowling        None      eng         435
# 3                 JK Rowling        None      eng        2690
# 4      W Frederick Zimmerman        None    en-US         152
# ...                      ...         ...      ...         ...
# 45740        Graham E Fuller        None      eng         301
# 45741      Gloria Vanderbilt        None      eng         112
# 45742          Frank Morison        None    en-US         193
# 45743     T Jefferson Parker        None      eng         341
# 45744        Abram N Shulsky        None    en-GB         262
#
#                 Publisher PublishYear  Rating CountsOfReview
# 0         Scholastic Inc.        2004    4.50          29770
# 1              Scholastic        2003    4.42            244
# 2         Scholastic Inc.        2004    4.57          37093
# 3              Scholastic        2004    4.78            166
# 4            Nimble Books        2005    3.79              1
# ...                   ...         ...     ...            ...
# 45740      Westview Press        1991    3.47              0
# 45741       Galahad Books        1970    3.42              3
# 45742  Zondervan Academic        1987    3.91             50
# 45743      Hyperion Books        2001    3.85            124
# 45744       Potomac Books        2002    3.63              8
#
# [45745 rows x 10 columns]

# %%
# View distinct languages
mainData.Language.unique()
# Out:
# array(['eng', 'en-US', 'fre', 'spa', 'mul', 'en-GB', 'grc', 'enm',
#        'en-CA', 'ger', 'jpn', 'ara', 'nl', 'zho', 'lat', 'por', 'srp',
#        'ita', 'rus', 'msa', 'glg', 'wel', 'swe', 'nor', 'kor', 'tur',
#        'gla', 'lit', 'per', 'pol', 'gle', 'cat', 'afr', 'ind', 'frs',
#        'sco', 'nav', 'gre', 'urd', 'elx', '--', 'cze', 'tlh', 'ang',
#        'hin', 'raj', 'nub', 'fin', 'dan', 'heb'], dtype=object)

# %%
# filter languages & drop duplicates
enLanguages=['en-US','eng','en-GB','en-CA']
mainData2=mainData[mainData.Language.isin(enLanguages)].copy()
# sorting will keep the records with most reviews when duplicates are dropped
mainData2.sort_values(by='CountsOfReview',ascending=0,inplace=True)
mainData2 = mainData[mainData.Language.isin(enLanguages)].drop_duplicates()
#mainData2.drop_duplicates(subset='ISBN',inplace=True)
#mainData2.drop_duplicates(subset='Name',inplace=True)
# Convert certain columns to INT
mainData2['CountsOfReview']=mainData2['CountsOfReview'].astype(int)
mainData2['pagesNumber']=mainData2['pagesNumber'].astype(int)
mainData2['PublishYear']=mainData2['PublishYear'].astype(int)
mainData2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42396 entries, 0 to 45744
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ISBN            42396 non-null  object
#  1   Name            42396 non-null  object
#  2   Authors         42396 non-null  object
#  3   Description     42396 non-null  object
#  4   Language        42396 non-null  object
#  5   pagesNumber     42396 non-null  int32
#  6   Publisher       42396 non-null  object
#  7   PublishYear     42396 non-null  int32
#  8   Rating          42396 non-null  float64
#  9   CountsOfReview  42396 non-null  int32
# dtypes: float64(1), int32(3), object(6)
# memory usage: 3.1+ MB

# %%
mainData2.sort_values(by='Name',inplace=True)

# %%
mainData2
# Out:
#              ISBN                                               Name  \
# 37344  4770027036                            / The Tale Of Genji: 22
# 14774  0821224964                                    Propos de Paris
# 1653   0743470796                       said the shotgun to the head
# 9926   0310243564  "A" Is for Abductive : The Language of the Eme...
# 21190  0446674060  "A" Is for Admission: The Insider's Guide to G...
# ...           ...                                                ...
# 42125  0811212386                     what it means to be avantgarde
# 37137  0345470583                       xxxHolic Vol 1 (xxxHOLiC #1)
# 37140  0345471199                      xxxHolic Vol 2  (xxxHOLiC #2)
# 37138  0345471814                      xxxHolic Vol 3  (xxxHOLiC #3)
# 37139  0345483359                      xxxHolic Vol 7  (xxxHOLiC #7)
#
#                     Authors Description Language  pagesNumber  \
# 37344           Waki Yamato        None      eng          160
# 14774  Henri CartierBresson        None      eng          168
# 1653          Saul Williams        None    en-US          192
# 9926          Leonard Sweet        None    en-US          338
# 21190    Michele A Hernndez        None    en-US          288
# ...                     ...         ...      ...          ...
# 42125           David Antin        None      eng          207
# 37137                 CLAMP        None    en-US          178
# 37140                 CLAMP        None      eng          208
# 37138                 CLAMP        None      eng          182
# 37139                 CLAMP        None      eng          192
#
#                                    Publisher  PublishYear  Rating  \
# 37344                                    講談社         2001    0.00
# 14774                               Bulfinch         1998    4.65
# 1653                               MTV Books         2003    4.22
# 9926                               Zondervan         2002    3.14
# 21190                           Warner Books         2009    3.75
# ...                                      ...          ...     ...
# 42125  New Directions Publishing Corporation         1993    4.44
# 37137                                Del Rey         2004    4.15
# 37140                                Del Rey         2004    4.19
# 37138                                Del Rey         2004    4.22
# 37139                          Del Rey Books         2006    4.33
#
#        CountsOfReview
# 37344               0
# 14774               3
# 1653              215
# 9926                3
# 21190               4
# ...               ...
# 42125               5
# 37137             352
# 37140              88
# 37138              71
# 37139              36
#
# [42396 rows x 10 columns]

# %%
dataCut=mainData2.head(50).reset_index()
dataCut
# Out:
#     index        ISBN                                               Name  \
# 0   37344  4770027036                            / The Tale Of Genji: 22
# 1   14774  0821224964                                    Propos de Paris
# 2    1653  0743470796                       said the shotgun to the head
# 3    9926  0310243564  "A" Is for Abductive : The Language of the Eme...
# 4   21190  0446674060  "A" Is for Admission: The Insider's Guide to G...
# 5   37264  0761128050          "A" Is for Adultery Angst and Adults Only
# 6   21196  0385471270  "An Honorable Profession": A Tribute to Robert...
# 7    9079  0070183171  "Dear Genius": A Memoir of My Life with Truman...
# 8   21491  0292713428  "Evil" Arabs in American Popular Film: Orienta...
# 9   22431  0590020498                             "I Can't" Said The Ant
# 10  44434  2718117524                  "Le Rouge Et Le Noir" De Stendhal
# 11  24024  0740715267  "My Teenage Son's Goal In Life Is To Make Me F...
# 12  33623  0226284352                      "Race" Writing and Difference
# 13   1412  0688093388  "Stand Back" Said the Elephant "I'm Going to S...
# 14  16971  0813523168                                            "Sweat"
# 15  37513  0813521378                   "Tell Me a Riddle": Tillie Olsen
# 16  34233  0140815244    "The Room In The Tower" And Other Ghost Stories
# 17  27415  0804723613  "This Culture of Ours": Intellectual Transitio...
# 18  26243  0818403128       "What's Happening to Me?" A Guide to Puberty
# 19   4072  0465083617  "Why Are All The Black Kids Sitting Together i...
# 20  40078  0758210264                            "Wicked" Women Whodunit
# 21  40079  0758209355                              "Wicked" Women on Top
# 22  14454  0807735663  "You Gotta Be the Book": Teaching Engaged and ...
# 23   3674  1592000673  $30 Film School: How to Write Direct Produce S...
# 24  43837  0571190146                                              'Art'
# 25  30345  0340677570  'Final Solution': Nazi Population Policy and t...
# 26  41112  0802841066  'In the Beginning' A Catholic Understanding of...
# 27  26817  0719059569  'Love Me Or Kill Me': Sarah Kane and the Theat...
# 28   1415  0385516487                                       'Salem's Lot
# 29  28016  0451095456                                       'Salem's Lot
# 30  12118  0060539763  'Scuse Me While I Whip This Out: Reflections o...
# 31  32468  0226294277  'There Ain't no Black in the Union Jack': The ...
# 32  20563  0192834495            'Tis Pity She's a Whore and Other Plays
# 33  22090  0684848783                                     'Tis: A Memoir
# 34  25073  0316107093  'Toons for Our Times: A Bloom County Book of H...
# 35  19549  0818402539  'Where Did I Come From?': The Facts of Life Wi...
# 36  35603  0552547344                              (Un)arranged Marriage
# 37  19085  0810992299                                        (un)Fashion
# 38  27604  1418508764  1 Corinthians: Godly Solutions For Church Prob...
# 39  26894  0977771504               1 Dead in Attic: PostKatrina Stories
# 40  41425  0849955386  1 Samuel: How One Godly Man Changed a Nation (...
# 41  12017  0785270221                          10 Commandments of Dating
# 42  37040  0446676675                          10 Days to Faster Reading
# 43  36783  0714844411                                         10 X 10  2
# 44   2106  042519745X                                      10 lb Penalty
# 45  18876  140120998X                        100 Bullets Vol 10: Decayed
# 46  18884  1401213154              100 Bullets Vol 11: Once Upon a Crime
# 47  18877  1563896451            100 Bullets Vol 1: First Shot Last Call
# 48  18879  1563897113             100 Bullets Vol 2: Split Second Chance
# 49  18883  1563898276             100 Bullets Vol 4: A Foregone Tomorrow
#
#                              Authors Description Language  pagesNumber  \
# 0                        Waki Yamato        None      eng          160
# 1               Henri CartierBresson        None      eng          168
# 2                      Saul Williams        None    en-US          192
# 3                      Leonard Sweet        None    en-US          338
# 4                 Michele A Hernndez        None    en-US          288
# 5                         Sara Midda        None    en-GB           64
# 6                    Pierre Salinger        None      eng          212
# 7                        Jack Dunphy        None      eng          275
# 8                 Tim Jon Semmerling        None      eng          303
# 9                      Polly Cameron        None      eng           36
# 10             Pierre Georges Castex        None      eng          187
# 11                        Dave Barry        None      eng          112
# 12              Henry Louis Gates Jr        None      eng          428
# 13                   Patricia Thomas        None      eng           32
# 14                Zora Neale Hurston        None      eng          233
# 15       Deborah Silverton Rosenfelt        None      eng          326
# 16                   Rudyard Kipling        None      eng           48
# 17                       Peter K Bol        None      eng          532
# 18                       Peter Mayle        None      eng           56
# 19              Beverly Daniel Tatum        None    en-US          320
# 20               MaryJanice Davidson        None      eng          320
# 21                     Tina  Donahue        None      eng          296
# 22                 Jeffrey D Wilhelm        None      eng          208
# 23                    Michael W Dean        None      eng          528
# 24                      Yasmina Reza        None      eng           63
# 25                           Gtz Aly        None      eng          305
# 26                      Benedict XVI        None      eng          100
# 27                Graham D  Saunders        None      eng          224
# 28                      Stephen King        None      eng          594
# 29                      Stephen King        None      eng          427
# 30                    Kinky Friedman        None    en-US          208
# 31                       Paul Gilroy        None      eng          280
# 32                        John  Ford        None      eng          416
# 33                     Frank McCourt        None      eng          367
# 34                 Berkeley Breathed        None      eng           96
# 35                       Peter Mayle        None      eng           48
# 36                          Bali Rai        None      eng          272
# 37                      Tibor Kalman        None      eng          224
# 38               John F MacArthur Jr        None      eng          128
# 39                       Chris  Rose        None      eng          158
# 40               John F MacArthur Jr        None      eng          130
# 41                         Ben Young        None      eng          175
# 42  The Princeton Language Institute        None      eng          206
# 43                     Phaidon Press        None      eng          468
# 44                      Dick Francis        None      eng          320
# 45                   Brian Azzarello        None      eng          192
# 46                   Brian Azzarello        None      eng          192
# 47                   Brian Azzarello        None      eng          128
# 48                   Brian Azzarello        None      eng          224
# 49                   Brian Azzarello        None      eng          264
#
#                                    Publisher  PublishYear  Rating  \
# 0                                        講談社         2001    0.00
# 1                                   Bulfinch         1998    4.65
# 2                                  MTV Books         2003    4.22
# 3                                  Zondervan         2002    3.14
# 4                               Warner Books         2009    3.75
# 5                 Workman Publishing Company         2002    3.59
# 6                          Main Street Books         1993    4.12
# 7                      McGraw-Hill Companies         1987    3.33
# 8                  University of Texas Press         2006    4.50
# 9                            Scholastic Inc.         1948    4.10
# 10                                 CDU SEDES         1995    3.73
# 11                 Andrews McMeel Publishing         2001    3.64
# 12      University of Chicago Press Journals         1992    4.06
# 13            William Morrow & Company, Inc.         1990    4.39
# 14                  Rutgers University Press         1997    4.06
# 15                  Rutgers University Press         1995    3.89
# 16                             Penguin Books         1995    3.46
# 17                 Stanford University Press         1994    4.54
# 18                    Carol Publishing Group         1989    4.13
# 19                               Basic Books         2003    4.22
# 20                                Kensington         2005    3.39
# 21                                Kensington         2005    3.34
# 22                    Teachers College Press         1996    3.95
# 23                          Cengage Learning         2003    3.50
# 24                             Faber & Faber         1997    3.82
# 25              Oxford University Press, USA         1999    4.00
# 26                                  Eerdmans         1995    4.35
# 27               Manchester University Press         2002    4.09
# 28                                 Doubleday         2005    4.25
# 29                                    Signet         1976    4.02
# 30                 William Morrow Paperbacks         2005    3.50
# 31               University of Chicago Press         1991    4.07
# 32                   Oxford University Press         1999    3.88
# 33                                  Scribner         1999    3.70
# 34                  Little Brown and Company         1984    4.40
# 35                    Carol Publishing Group         1990    4.14
# 36                                     Corgi         2001    3.35
# 37                           Harry N. Abrams         2005    4.28
# 38                             Thomas Nelson         2006    4.19
# 39                          Simon & Schuster         2005    4.12
# 40                  Thomas Nelson Publishers         2012    4.11
# 41  Nelson Reference & Electronic Publishing         1999    3.89
# 42                  Grand Central Publishing         2001    3.87
# 43                             Phaidon Press         2005    4.03
# 44                        G.P. Putnam's Sons         2004    3.91
# 45                                   Vertigo         2006    4.07
# 46                                   Vertigo         2007    4.05
# 47                                   Vertigo         2000    3.84
# 48                                   Vertigo         2000    4.09
# 49                                   Vertigo         2002    4.10
#
#     CountsOfReview
# 0                0
# 1                3
# 2              215
# 3                3
# 4                4
# 5                1
# 6                2
# 7                6
# 8                0
# 9               12
# 10              25
# 11              10
# 12               2
# 13             134
# 14              52
# 15               4
# 16               2
# 17               2
# 18              35
# 19             717
# 20              16
# 21               7
# 22              13
# 23               4
# 24             176
# 25               0
# 26              38
# 27               5
# 28             592
# 29               0
# 30               0
# 31               9
# 32              14
# 33             104
# 34              27
# 35             128
# 36              99
# 37              13
# 38               0
# 39             310
# 40               1
# 41              14
# 42             130
# 43               1
# 44             179
# 45              42
# 46              51
# 47             404
# 48             154
# 49              58
